# %%
#Include the UNSflow libraries
#Pkg.clone("git://github.com/KiranUofG/UNSflow")
include("../src/UNSflow.jl")
using UNSflow
# Out:
# WARNING: Method definition pcws_1(Any, Any

# %%
# Insert stating constants

    #Static constants from case 6 (notebook "KLB - static SD7003 test cases") are used
    alpha1, s1, s2, model = 7., 5.,  5., "Sheng"
    param = [-0.0704412  -0.011237  0.0739017  1.88094]
        # 1: k0, 2: k1, 3: k2, 4: m
    #Parameters from [2] for NACA 0015: alpha1 = 15.25, s1 = 3.0, s2 = 2.3, k0 = 0, k1 = -0.135, k2 = 0.04, m = 2 
    #[2] Z. Liu, J. C. S. Lai, J. Young, and F.-B. Tian, “Discrete Vortex Method with Flow Separation Corrections for Flapping-Foil Power Generators,” AIAA Journal, vol. 55, no. 2, pp. 410–418, Feb. 2017.
# Out:
# , Any) in module UNSflow at C:\Users\pepe\Documents\GitHub\kramesh\UNSflow\src\calculations.jl:3170 overwritten at C:\Users\pepe\Documents\GitHub\kramesh\UNSflow\src\calculations.jl:3173.
# WARNING: Method definition pcws_2(Any, Any, Any) in module UNSflow at C:\Users\pepe\Documents\GitHub\kramesh\UNSflow\src\calculations.jl:3171
# 1×4 Array{Float64,2}:
#  -0.0704412  -0.011237  0.0739017  1.88094

# %%
alphadef = ConstDef(12.*pi/180)
hdef = ConstDef(0.)
udef = ConstDef(1.) #Freestream velocity is a constant. Set as constant = 1

#The full kinematics are collected as:
full_kinem = KinemDef(alphadef, hdef, udef)

pvt = 0.25 #Leading edge
lespcrit = [5;] #Note that the value is entered as an array. 
time_total = 3.
#nsteps = Int(round(time_total/0.015))
nsteps = 5
# Out:
#  overwritten at C:\Users\pepe\Documents\GitHub\kramesh\UNSflow\src\calculations.jl:3174.
# 5

# %%
alphadef = ConstDef(12.*pi/180)
hdef = ConstDef(0.)
udef = ConstDef(1.) #Freestream velocity is a constant. Set as constant = 1

#The full kinematics are collected as:
full_kinem = KinemDef(alphadef, hdef, udef)

pvt = 0.25 #Leading edge
lespcrit = [0.08;] #Note that the value is entered as an array. 
time_total = 3.
#nsteps = Int(round(time_total/0.015))
# Out:
# 3.0

# %%
# The argument "FlatPlate" provides zero camber. To use an airfoil, specify the coordinate file which should be
#in the same folder. For eg. "sd7003.dat". 
#The XFOIL convention must be used for the coordinate: TE->Upper surface->LE->Lower surface->TE
nsteps=100
surf = TwoDSurf("n0012.dat", pvt, full_kinem,lespcrit)
curfield = TwoDFlowField()
del = DelVortDef(1, 500, 10)

#Now the code is run as :
#The variables mat, surf and curfield are returned
        
matldvm, surf, curfield = ldvm(surf, curfield, nsteps; delvort = del);

# %%
view_vorts(surf,curfield)
axis("equal")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000001E860278>)
# (-2.623302171813337,0.11753128622821671,-0.33024175738913303,0.12146002195815468)

# %%
plot(matldvm[:,9], label="TEV")
plot(matldvm[:,10], label="LEV")
legend()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000001EAA3400>)
# PyObject <matplotlib.legend.Legend object at 0x000000001ECD3AC8>

# %%
# The argument "FlatPlate" provides zero camber. To use an airfoil, specify the coordinate file which should be
#in the same folder. For eg. "sd7003.dat". 
#The XFOIL convention must be used for the coordinate: TE->Upper surface->LE->Lower surface->TE
nsteps = 100
surf = TwoDSurf("n0012.dat", pvt, full_kinem,lespcrit)
curfield = TwoDFlowField()
del = DelVortDef(1, 500, 10)

#Now the code is run as :
#The variables mat, surf and curfield are returned
        
mat2d, surf, curfield = ldvm_spv(surf, curfield,param[1,:], nsteps; delvort = del, alpha1 = alpha1, S1 = s1, S2 = s2, model="Sheng", aoa = 2, modelF = "dymore", forcefsep = true, fsep_forced = 0.05);

# %%
view_vorts(surf,curfield)
axis("equal")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000001ED67CF8>)
# (-2.6187577888293965,0.11967700212961764,-0.39590866839107663,0.10624486211137638)

# %%
plot(mat2d[:,1],mat2d[:,9],label="Static f")
plot(mat2d[:,1],mat2d[:,10],label="Dynamic f")

#plot(mat2d[:,1],f0sep2, label="preview of static f")
xlabel("Nondimensional time t*")
ylabel("Separation point x/c")
legend()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000001EFAD438>)
# PyObject <matplotlib.legend.Legend object at 0x000000001F26E630>

# %%
plot(mat2d[:,11],label="TEV")
plot(mat2d[:,12],label="SPV")
legend()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000001E9EFDD8>)
# PyObject <matplotlib.legend.Legend object at 0x00000000247407F0>

# %%
# The argument "FlatPlate" provides zero camber. To use an airfoil, specify the coordinate file which should be
#in the same folder. For eg. "sd7003.dat". 
#The XFOIL convention must be used for the coordinate: TE->Upper surface->LE->Lower surface->TE
nsteps = 100
surf = TwoDSurf("n0012.dat", pvt, full_kinem,lespcrit)
curfield = TwoDFlowField()
del = DelVortDef(1, 500, 10)

#Now the code is run as :
#The variables mat, surf and curfield are returned
        
mat2d, surf, curfield = ldvm_spv(surf, curfield,param[1,:], nsteps; delvort = del, alpha1 = alpha1, S1 = s1, S2 = s2, model="Sheng", aoa = 2, modelF = "dymore", forcefsep = true, fsep_forced = 0.5);

# %%
view_vorts(surf,curfield)
axis("equal")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000001EFADAC8>)
# (-2.618705253475804,0.11857375970417484,-0.38788601006667006,0.07286739312192501)

# %%
plot(mat2d[:,1],mat2d[:,9],label="Static f")
plot(mat2d[:,1],mat2d[:,10],label="Dynamic f")

#plot(mat2d[:,1],f0sep2, label="preview of static f")
xlabel("Nondimensional time t*")
ylabel("Separation point x/c")
legend()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000001F0425C0>)
# PyObject <matplotlib.legend.Legend object at 0x0000000024CCF6A0>

# %%
plot(mat2d[:,11],label="TEV")
plot(mat2d[:,12],label="SPV")
legend()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x00000000247C0438>)
# PyObject <matplotlib.legend.Legend object at 0x0000000024F4D2E8>
