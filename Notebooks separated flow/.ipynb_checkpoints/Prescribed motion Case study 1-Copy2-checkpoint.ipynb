# %%
#Include the UNSflow libraries
#Pkg.clone("git://github.com/KiranUofG/UNSflow")
include("../src/UNSflow.jl")
using UNSflow
# Out:
# WARNING: Method definition pcws_1(Any, Any, Any)

# %% [markdown]
# #### This notebook tests LDVM solver with KLB for prescribed motions. Results are compared to the case study 1 from [1]. Parameters of motion are presented in Table 1.
#
# [1] K. Ramesh, A. Gopalarathnam, K. Granlund, M. V. Ol, and J. R. Edwards, “Discrete-vortex method with novel shedding criterion for unsteady aerofoil flows with intermittent leading-edge vortex shedding,” Journal of Fluid Mechanics, vol. 751, pp. 500–538, Jul. 2014.
#
#
# #### Table 1
# |--|--|
# |:----:|:-------:|
# |Airfoil|SD-7003|
# |Motion|Eldredge ramp|
# |Smoothing parameter a|11|
# |Amplitude|25 deg|
# |Pivot point| LE|
# |Nondim. pitch rate k|0.11|
# |Reynolds number| 30k|
# |LESP| 0.18|

# %%
# Insert stating constants

    #Static constants from case 6 (notebook "KLB - static SD7003 test cases") are used
    alpha1, s1, s2, model = 10.5,        3.06665,  3.70008, "Original"
    param = [-0.0704412  -0.011237  0.0739017  1.88094]
        # 1: k0, 2: k1, 3: k2, 4: m
    #Parameters from [2] for NACA 0015: alpha1 = 15.25, s1 = 3.0, s2 = 2.3, k0 = 0, k1 = -0.135, k2 = 0.04, m = 2 
    #[2] Z. Liu, J. C. S. Lai, J. Young, and F.-B. Tian, “Discrete Vortex Method with Flow Separation Corrections for Flapping-Foil Power Generators,” AIAA Journal, vol. 55, no. 2, pp. 410–418, Feb. 2017.
# Out:
#  in module UNSflow at C:\Users\pepe\Documents\GitHub\kramesh\UNSflow\src\calculations.jl:3093 overwritten at C:\Users\pepe\Documents\GitHub\kramesh\UNSflow\src\calculations.jl:3096.
# WARNING: Method definition pcws_2(Any, Any, Any) in module UNSflow at C:\Users\pepe\Documents\GitHub\kramesh\UNSflow\src\calculations.jl:3094 overwritten
# 1×4 Array{Float64,2}:
#  -0.0704412  -0.011237  0.0739017  1.88094

# %%
alphadef = EldRampReturnDef(25.*pi/180.,0.11, 11.)
hdef = ConstDef(0.)
udef = ConstDef(1.) #Freestream velocity is a constant. Set as constant = 1

#The full kinematics are collected as:
full_kinem = KinemDef(alphadef, hdef, udef)

pvt = 0. #Leading edge
lespcrit = [0.18;] #Note that the value is entered as an array. 

# The argument "FlatPlate" provides zero camber. To use an airfoil, specify the coordinate file which should be
#in the same folder. For eg. "sd7003.dat". 
#The XFOIL convention must be used for the coordinate: TE->Upper surface->LE->Lower surface->TE
surf = TwoDSurf("sd7003_fine.dat", pvt, full_kinem,lespcrit)
curfield = TwoDFlowField()
del = DelVortDef(1, 500, 10)

#Specify simulation details - time step, and number of steps.
#The default nondimensional timestep is 0.015. There is usually no need to change this. 
dtstar = find_tstep(alphadef)
time_total = 7.
nsteps = Int(round(time_total/dtstar))
# Out:
#  at C:\Users\pepe\Documents\GitHub\kramesh\UNSflow\src\calculations.jl:3097.
# 467

# %%
#Now the code is run as :
#The variables mat, surf and curfield are returned
        
mat, surf, curfield = ldvm_klb_tr(surf, curfield,param[1,:], nsteps, dtstar; delvort = del, alpha1 = alpha1, S1 = s1, S2 = s2, model=model, aoa = 1)
# Out:
# (
0.02,0.0,0.0),UNSflow.TwoDVort(-8.00164,0.000622842,0.00157604,0.02,0.0,0.0),UNSflow.TwoDVort(-7.99854,0.00115816,0.00216258,0.02,0.0,0.0),UNSflow.TwoDVort(-7.99442,0.00174831,0.00230611,0.02,0.0,0.0),UNSflow.TwoDVort(-7.98928,0.00243644,0.00214393,0.02,0.0,0.0),UNSflow.TwoDVort(-7.98314,0.00318061,0.00240725,0.02,0.0,0.0),UNSflow.TwoDVort(-7.97601,0.00396416,0.0029225,0.02,0.0,0.0),UNSflow.TwoDVort(-7.9679,0.00479012,0.00300744,0.02,0.0,0.0),UNSflow.TwoDVort(-7.95883,0.00564767,0.00289957,0.02,0.0,0.0)  …  UNSflow.TwoDVort(-7.05117,0.00289946,-0.000509689,0.02,0.0,0.0),UNSflow.TwoDVort(-7.0421,0.0023962,-0.000529499,0.02,0.0,0.0),UNSflow.TwoDVort(-7.03399,0.00191153,-0.000449007,0.02,0.0,0.0),UNSflow.TwoDVort(-7.02686,0.00145911,-0.000387693,0.02,0.0,0.0),UNSflow.TwoDVort(-7.02072,0.00105341,-0.000356378,0.02,0.0,0.0),UNSflow.TwoDVort(-7.01558,0.000706674,-0.000268988,0.02,0.0,0.0),UNSflow.TwoDVort(-7.01146,0.000427175,-0.000150651,0.02,0.0,0.0),UNSflow.TwoDVort(-7.00836,0.000218957,-8.1031e-5,0.02,0.0,0.0),UNSflow.TwoDVort(-7.00629,8.18782e-5,-4.57467e-5,0.02,0.0,0.0),UNSflow.TwoDVort(-7.00526,1.54577e-5,-1.38128e-5,0.02,0.0,0.0)],[0.18],Int8[0],[0.0,0.0]),UNSflow.TwoDFlowField(UNSflow.ConstDef(0.0),UNSflow.ConstDef(0.0),[0.0],[0.0],UNSflow.TwoDVort[UNSflow.TwoDVort(-0.227533,0.363252,-0.0145628,0.02,-0.0397214,0.0415004),UNSflow.TwoDVort(-0.257923,0.392492,-0.000525495,0.02,-0.0892159,0.00394857),UNSflow.TwoDVort(-0.200707 ...

# %%
 alphadef = EldRampReturnDef(25.*pi/180.,0.11, 11.)
hdef = ConstDef(0.)
udef = ConstDef(1.) #Freestream velocity is a constant. Set as constant = 1

#The full kinematics are collected as:
full_kinem = KinemDef(alphadef, hdef, udef)

pvt = 0. #Leading edge
lespcrit = [0.18;] #Note that the value is entered as an array. 

# The argument "FlatPlate" provides zero camber. To use an airfoil, specify the coordinate file which should be
#in the same folder. For eg. "sd7003.dat". 
#The XFOIL convention must be used for the coordinate: TE->Upper surface->LE->Lower surface->TE
surf = TwoDSurf("sd7003_fine.dat", pvt, full_kinem,lespcrit)
curfield = TwoDFlowField()
del = DelVortDef(1, 500, 10)

#Specify simulation details - time step, and number of steps.
#The default nondimensional timestep is 0.015. There is usually no need to change this. 
dtstar = find_tstep(alphadef)
time_total = 7.
nsteps = Int(round(time_total/dtstar))  
mataoa2, surf, curfield = ldvm_klb_tr(surf, curfield,param[1,:], nsteps, dtstar; delvort = del, alpha1 = alpha1, S1 = s1, S2 = s2, model=model, aoa = 2)
# Out:
# (
# [0.015 3.88004e-12 … 0.98516 0.999926; 0.03 5.39695e-12 … 0.985193 0.999853; … ; 6.99 3.05084e-11 … 0.98632 0.873883; 7.005 2.19333e-11 … 0.98632 0.874444],
#
0.02,0.0,0.0),UNSflow.TwoDVort(-8.00164,0.000622842,0.00157604,0.02,0.0,0.0),UNSflow.TwoDVort(-7.99854,0.00115816,0.00216258,0.02,0.0,0.0),UNSflow.TwoDVort(-7.99442,0.00174831,0.00230611,0.02,0.0,0.0),UNSflow.TwoDVort(-7.98928,0.00243644,0.00214393,0.02,0.0,0.0),UNSflow.TwoDVort(-7.98314,0.00318061,0.00240725,0.02,0.0,0.0),UNSflow.TwoDVort(-7.97601,0.00396416,0.0029225,0.02,0.0,0.0),UNSflow.TwoDVort(-7.9679,0.00479012,0.00300744,0.02,0.0,0.0),UNSflow.TwoDVort(-7.95883,0.00564767,0.00289957,0.02,0.0,0.0)  …  UNSflow.TwoDVort(-7.05117,0.00289946,-0.000509689,0.02,0.0,0.0),UNSflow.TwoDVort(-7.0421,0.0023962,-0.000529499,0.02,0.0,0.0),UNSflow.TwoDVort(-7.03399,0.00191153,-0.000449007,0.02,0.0,0.0),UNSflow.TwoDVort(-7.02686,0.00145911,-0.000387693,0.02,0.0,0.0),UNSflow.TwoDVort(-7.02072,0.00105341,-0.000356378,0.02,0.0,0.0),UNSflow.TwoDVort(-7.01558,0.000706674,-0.000268988,0.02,0.0,0.0),UNSflow.TwoDVort(-7.01146,0.000427175,-0.000150651,0.02,0.0,0.0),UNSflow.TwoDVort(-7.00836,0.000218957,-8.1031e-5,0.02,0.0,0.0),UNSflow.TwoDVort(-7.00629,8.18782e-5,-4.57467e-5,0.02,0.0,0.0),UNSflow.TwoDVort(-7.00526,1.54577e-5,-1.38128e-5,0.02,0.0,0.0)],[0.18],Int8[0],[0.0,0.0]),UNSflow.TwoDFlowField(UNSflow.ConstDef(0.0),UNSflow.ConstDef(0.0),[0.0],[0.0],UNSflow.TwoDVort[UNSflow.TwoDVort(-0.227533,0.363252,-0.0145628,0.02,-0.0397214,0.0415004),UNSflow.TwoDVort(-0.257923,0.392492,-0.000525495,0.02,-0.0892159,0.00394857),UNSflow.TwoDVort(-0.200707 ...

# %%
alphadef = EldRampReturnDef(25.*pi/180.,0.11, 11.)
hdef = ConstDef(0.)
udef = ConstDef(1.) #Freestream velocity is a constant. Set as constant = 1

#The full kinematics are collected as:
full_kinem = KinemDef(alphadef, hdef, udef)

pvt = 0. #Leading edge
lespcrit = [0.18;] #Note that the value is entered as an array. 

# The argument "FlatPlate" provides zero camber. To use an airfoil, specify the coordinate file which should be
#in the same folder. For eg. "sd7003.dat". 
#The XFOIL convention must be used for the coordinate: TE->Upper surface->LE->Lower surface->TE
surf2 = TwoDSurf("sd7003_fine.dat", pvt, full_kinem,lespcrit)
curfield2 = TwoDFlowField()
del = DelVortDef(1, 500, 10)

#Specify simulation details - time step, and number of steps.
#The default nondimensional timestep is 0.015. There is usually no need to change this. 
dtstar = find_tstep(alphadef)
time_total = 7.
nsteps = Int(round(time_total/dtstar))
mat2, surf2, curfield2 = ldvm(surf2, curfield2, nsteps, dtstar; delvort = del)
# Out:
# (
# [0.015 3.88004e-12 … -0.00313718 -1.03687; 0.03 5.39695e-12 … -0.00310377 -0.0731614; … ; 6.99 3.05084e-11 … -0.0020327 -0.131838; 7.005 2.19333e-11 … -0.00203312 -0.132138],
#
# UNSflow.TwoDSurf(1.0,1.0,"sd7003_fine.dat",0.0,70,35,UNSflow.KinemDef(UNSflow.EldRampReturnDef(0.4363323129985824,0.11,11.0),UNSflow.ConstDef(0.0),UNSflow.ConstDef(1.0)),[0.0,-5.99471e-6,0.000351646,0.000894037,0.00142227,0.00207434,0.00279854,0.00356268,0.00436563,0.0052146  …  0.00264481,0.00214758,0.00167547,0.00124276,
,0.0,0.0)  …  UNSflow.TwoDVort(-7.05117,0.00289946,-0.000509689,0.02,0.0,0.0),UNSflow.TwoDVort(-7.0421,0.0023962,-0.000529499,0.02,0.0,0.0),UNSflow.TwoDVort(-7.03399,0.00191153,-0.000449007,0.02,0.0,0.0),UNSflow.TwoDVort(-7.02686,0.00145911,-0.000387693,0.02,0.0,0.0),UNSflow.TwoDVort(-7.02072,0.00105341,-0.000356378,0.02,0.0,0.0),UNSflow.TwoDVort(-7.01558,0.000706674,-0.000268988,0.02,0.0,0.0),UNSflow.TwoDVort(-7.01146,0.000427175,-0.000150651,0.02,0.0,0.0),UNSflow.TwoDVort(-7.00836,0.000218957,-8.1031e-5,0.02,0.0,0.0),UNSflow.TwoDVort(-7.00629,8.18782e-5,-4.57467e-5,0.02,0.0,0.0),UNSflow.TwoDVort(-7.00526,1.54577e-5,-1.38128e-5,0.02,0.0,0.0)],[0.18],Int8[0],[0.0,0.0]),UNSflow.TwoDFlowField(UNSflow.ConstDef(0.0),UNSflow.ConstDef(0.0),[0.0],[0.0],UNSflow.TwoDVort[UNSflow.TwoDVort(-0.227533,0.363252,-0.0145628,0.02,-0.0397214,0.0415004),UNSflow.TwoDVort(-0.257923,0.392492,-0.000525495,0.02,-0.0892159,0.00394857),UNSflow.TwoDVort(-0.200707 ...

# %%
plot(mat[:,1],mat2[:,2]*180/pi)
xlabel("Nondimensional time t*")
ylabel("Angle of attack in deg")
legend()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000001BD8E240>)

# %%
plot(mat[:,1],mat[:,9],label="f0sep based on AoA")
plot(mat[:,1],mat[:,10], label="fsep based on AoA")
plot(mat[:,1],mataoa2[:,9], label="f0sep based on effective AoA")
plot(mat[:,1],mataoa2[:,10], label ="fsep based on effective AoA")
legend()
xlabel("Nondimensional time t*")
ylabel("Separation point x/c")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000001BFFEE48>)
# PyObject <matplotlib.text.Text object at 0x000000001C0B1E10>

# %%
plot(mat[:,1],mat[:,5],label="LDVM with KLB")
plot(mat[:,1],mataoa2[:,5],label="LDVM with KLB effective AoA")
plot(mat2[:,1],mat2[:,5],label="LDVM")
xlabel("Nondimensional time t*")
ylabel("LESP")
legend()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000001BFFEF98>)
# PyObject <matplotlib.legend.Legend object at 0x000000001C5BCD68>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#plot(mat[:,1],mat[:,6],label="LDVM with KLB")
plot(mataoa2[:,1],mataoa2[:,6],label="LDVM with KLB eff AoA")
plot(mat2[:,1],mat2[:,6],label="LDVM")
xlabel("Nondimensional time t*")
ylabel("Lift coefficient CL")
legend()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000001CAF3278>)
# PyObject <matplotlib.legend.Legend object at 0x000000001CC3DDA0>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#plot(mat[:,1],mat[:,7],label="LDVM with KLB")
plot(mataoa2[:,1],mataoa2[:,7],label="LDVM with KLB eff AoA")
plot(mat2[:,1],mat2[:,7],label="LDVM")
xlabel("Nondimensional time t*")
ylabel("Drag coefficient CD")
legend()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000001CDB8E10>)
# PyObject <matplotlib.legend.Legend object at 0x000000001D04DB00>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plot(mat[:,1],mat[:,8],label="LDVM with KLB")
plot(mat[:,1],mataoa2[:,8],label="LDVM with KLB eff AoA")
plot(mat2[:,1],mat2[:,8],label="LDVM")
xlabel("Nondimensional time t*")
ylabel("Moment coefficient CM")
legend()

# %% [markdown]
# ![image.png](attachment:image.png)
