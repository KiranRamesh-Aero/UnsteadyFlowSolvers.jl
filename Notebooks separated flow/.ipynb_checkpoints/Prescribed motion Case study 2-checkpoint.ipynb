# %%
#Include the UNSflow libraries
#Pkg.clone("git://github.com/KiranUofG/UNSflow")
include("../src/UNSflow.jl")
using UNSflow
# Out:
# WARNING: Method definition pcws_1(Any, Any, Any) in module UNSflow at /home/maciej/kramesh/UNSflow/src/calculations.jl:3093 overwritten at /home/maciej/kramesh/UNSflow/src/calculations.jl:3096.
# WARNING: Method definition pcws_2(Any, Any, Any) in module UNSflow at /home/maciej/kramesh/UNSflow/src/calculations.jl:3094 overwritten at /home/maciej/kramesh/UNSflow/src/calculations.jl:3097.

# %% [markdown]
# #### This notebook tests LDVM solver with KLB for prescribed motions. Results are compared to the case study 2 from [1]. Parameters of motion are presented in Table 1.
#
# [1] K. Ramesh, A. Gopalarathnam, K. Granlund, M. V. Ol, and J. R. Edwards, “Discrete-vortex method with novel shedding criterion for unsteady aerofoil flows with intermittent leading-edge vortex shedding,” Journal of Fluid Mechanics, vol. 751, pp. 500–538, Jul. 2014.
#
#
# #### Table 1
# |--|--|
# |:----:|:-------:|
# |Airfoil|SD-7003|
# |Motion|Eldredge ramp|
# |Smoothing parameter a|2|
# |Amplitude|90 deg|
# |Pivot point| TE|
# |Nondim. pitch rate k|0.4|
# |Reynolds number| 100k|
# |LESP| 0.14|

# %%
# Insert stating constants

    #Static constants from case 6 (notebook "KLB - static SD7003 test cases") are used
    alpha1, s1, s2, model = 10.5,        3.06665,  3.70008, "Original"
    param = [-0.0704412  -0.011237  0.0739017  1.88094]
        # 1: k0, 2: k1, 3: k2, 4: m
    #Parameters from [2] for NACA 0015: alpha1 = 15.25, s1 = 3.0, s2 = 2.3, k0 = 0, k1 = -0.135, k2 = 0.04, m = 2 
    #[2] Z. Liu, J. C. S. Lai, J. Young, and F.-B. Tian, “Discrete Vortex Method with Flow Separation Corrections for Flapping-Foil Power Generators,” AIAA Journal, vol. 55, no. 2, pp. 410–418, Feb. 2017.
# Out:
# 1×4 Array{Float64,2}:
#  -0.0704412  -0.011237  0.0739017  1.88094

# %%
alphadef = EldRampReturnDef(90.*pi/180.,0.4, 2.)
hdef = ConstDef(0.)
udef = ConstDef(1.) #Freestream velocity is a constant. Set as constant = 1

#The full kinematics are collected as:
full_kinem = KinemDef(alphadef, hdef, udef)

pvt = 1. #Trailing edge
lespcrit = [0.14;] #Note that the value is entered as an array. 

# The argument "FlatPlate" provides zero camber. To use an airfoil, specify the coordinate file which should be
#in the same folder. For eg. "sd7003.dat". 
#The XFOIL convention must be used for the coordinate: TE->Upper surface->LE->Lower surface->TE
surf = TwoDSurf("sd7003_fine.dat", pvt, full_kinem,lespcrit)
curfield = TwoDFlowField()
del = DelVortDef(1, 500, 10)

#Specify simulation details - time step, and number of steps.
#The default nondimensional timestep is 0.015. There is usually no need to change this. 
dtstar = find_tstep(alphadef)
time_total = 8.
nsteps = Int(round(time_total/dtstar))
# Out:
# 1067

# %%
#Now the code is run as :
#The variables mat, surf and curfield are returned
        
mat, surf, curfield = ldvm_klb_tr(surf, curfield,param[1,:], nsteps, dtstar; delvort = del, alpha1 = alpha1, S1 = s1, S2 = s2, model=model, aoa = 1)
],[0.534927,-0.409733,0.0845602],UNSflow.TwoDVort[UNSflow.TwoDVort(-9.00224,2.261e-5,-0.0103516,0.02,0.0,0.0),UNSflow.TwoDVort(-9.00121,0.000198407,-0.0105364,0.02,0.0,0.0),UNSflow.TwoDVort(-8.99914,0.00064837,-0.010234,0.02,0.0,0.0),UNSflow.TwoDVort(-8.99604,0.0011836,-0.0096168,0.02,0.0,0.0),UNSflow.TwoDVort(-8.99192,0.00177365,-0.00945564,0.02,0.0,0.0),UNSflow.TwoDVort(-8.98678,0.00246165,-0.00956313,0.02,0.0,0.0),UNSflow.TwoDVort(-8.98064,0.00320567,-0.00920434,0.02,0.0,0.0),UNSflow.TwoDVort(-8.97351,0.00398903,-0.00862627,0.02,0.0,0.0),UNSflow.TwoDVort(-8.9654,0.00481478,-0.00850233,0.02,0.0,0.0),UNSflow.TwoDVort(-8.95633,0.0056721,-0.00849755,0.02,0.0,0.0)  …  UNSflow.TwoDVort(-8.04867,0.00290065,0.00783113,0.02,0.0,0.0),UNSflow.TwoDVort(-8.0396,0.00239715,0.00660391,0.02,0.0,0.0),UNSflow.TwoDVort(-8.03149,0.00191227,0.00538824,0.02,0.0,0.0),UNSflow.TwoDVort(-8.02436,0.00145967,0.00415365,0.02,0.0,0.0),UNSflow.TwoDVort(-8.01822,0.00105382,0.00301856,0.02,0.0,0.0),UNSflow.TwoDVort(-8.01308,0.000706946,0.00204447,0.02,0.0,0.0),UNSflow.TwoDVort(-8.00896,0.000427341,0.00123872,0.02,0.0,0.0),UNSflow.TwoDVort(-8.00586,0.000219044,0.000620687,0.02,0.0,0.0),UNSflow.TwoDVort(-8.00379,8.19114e-5,0.000222981,0.02,0.0,0.0),UNSflow.TwoDVort(-8.00276,1.54643e-5,4.12776e-5,0.02,0.0,0.0)],[0.14],Int8[0],[0.0,0.0]),UNSflow.TwoDFlowField(UNSflow.ConstDef(0.0),UNSflow.ConstDef(0.0),[0.0],[0.0],UNSflow.TwoDVort[UNSflow.TwoDVort(-0.33901,0.337035,-0.0154095,0.02,-0.051131,0.0392424),UNSflow.TwoDVort(-0.356357,0.337233,0.00134617,0.02,-0.0583432,-0.0411836),UNSflow.TwoDVort(-0.310102,0.325387,-0.000521255,0.02,-0.0120126,0.118784),UNSflow ...

# %%
surf2 = TwoDSurf("sd7003_fine.dat", pvt, full_kinem,lespcrit)
curfield2 = TwoDFlowField()
del = DelVortDef(1, 500, 10)

#Specify simulation details - time step, and number of steps.
#The default nondimensional timestep is 0.015. There is usually no need to change this. 
dtstar = find_tstep(alphadef)
time_total = 8.
nsteps = Int(round(time_total/dtstar))
mat2, surf2, curfield2 = ldvm(surf2, curfield2, nsteps, dtstar; delvort = del)
# Out:
# (
# [0.0075 0.00383668 … -0.00296925 -1.51977; 0.015 0.00395241 … -0.0041419 0.0122804; … ; 7.995 8.4988e-5 … -0.0793821 -0.35472; 8.0025 8.24768e-5 … -0.0790797 -0.361438],
#
0.0,0.0),UNSflow.TwoDVort(-8.98064,0.00320567,-0.00920434,0.02,0.0,0.0),UNSflow.TwoDVort(-8.97351,0.00398903,-0.00862627,0.02,0.0,0.0),UNSflow.TwoDVort(-8.9654,0.00481478,-0.00850233,0.02,0.0,0.0),UNSflow.TwoDVort(-8.95633,0.0056721,-0.00849755,0.02,0.0,0.0)  …  UNSflow.TwoDVort(-8.04867,0.00290065,0.00783113,0.02,0.0,0.0),UNSflow.TwoDVort(-8.0396,0.00239715,0.00660391,0.02,0.0,0.0),UNSflow.TwoDVort(-8.03149,0.00191227,0.00538824,0.02,0.0,0.0),UNSflow.TwoDVort(-8.02436,0.00145967,0.00415365,0.02,0.0,0.0),UNSflow.TwoDVort(-8.01822,0.00105382,0.00301856,0.02,0.0,0.0),UNSflow.TwoDVort(-8.01308,0.000706946,0.00204447,0.02,0.0,0.0),UNSflow.TwoDVort(-8.00896,0.000427341,0.00123872,0.02,0.0,0.0),UNSflow.TwoDVort(-8.00586,0.000219044,0.000620687,0.02,0.0,0.0),UNSflow.TwoDVort(-8.00379,8.19114e-5,0.000222981,0.02,0.0,0.0),UNSflow.TwoDVort(-8.00276,1.54643e-5,4.12776e-5,0.02,0.0,0.0)],[0.14],Int8[0],[0.0,0.0]),UNSflow.TwoDFlowField(UNSflow.ConstDef(0.0),UNSflow.ConstDef(0.0),[0.0],[0.0],UNSflow.TwoDVort[UNSflow.TwoDVort(-0.33901,0.337035,-0.0154095,0.02,-0.051131,0.0392424),UNSflow.TwoDVort(-0.356357,0.337233,0.00134617,0.02,-0.0583432,-0.0411836),UNSflow.TwoDVort(-0.310102,0.325387,-0.000521255,0.02,-0.0120126,0.118784),UNSflow ...

# %%
plot(mat[:,1],mat[:,2]*180/pi)
xlabel("Nondimensional time t*")
ylabel("Angle of attack in deg")
legend()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f5339565ac8>)

# %%
#plot(mat[:,1],mat[:,5]*180/pi)
plot(mat[:,1],mat[:,9])
plot(mat[:,1],mat[:,10])
xlabel("Angle of attack in deg")
ylabel("Separation point position f, x/c")
legend()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f532392f2b0>)

# %%
plot(mat[:,1],mat[:,5],label="LDVM with KLB")
plot(mat2[:,1],mat2[:,5],label="LDVM")
xlabel("Nondimensional time t*")
ylabel("LESP")
legend()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f531fcf1e10>)
# PyObject <matplotlib.legend.Legend object at 0x7f531fc5f278>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plot(mat[:,1],mat[:,6],label="LDVM with KLB")
plot(mat2[:,1],mat2[:,6],label="LDVM")
xlabel("Nondimensional time t*")
ylabel("Lift coefficient CL")
legend()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f5339ac57f0>)
# PyObject <matplotlib.legend.Legend object at 0x7f531fc184a8>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plot(mat[:,1],mat[:,7],label="LDVM with KLB")
plot(mat2[:,1],mat2[:,7],label="LDVM")
xlabel("Nondimensional time t*")
ylabel("Drag coefficient CD")
legend()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f531fcdb9b0>)
# PyObject <matplotlib.legend.Legend object at 0x7f531fb520b8>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plot(mat[:,1],mat[:,8],label="LDVM with KLB")
plot(mat2[:,1],mat2[:,8],label="LDVM")
xlabel("Nondimensional time t*")
ylabel("Moment coefficient CM")
legend()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f531fb6ac88>)
# PyObject <matplotlib.legend.Legend object at 0x7f531fa80710>

# %% [markdown]
# ![image.png](attachment:image.png)
